# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianLarssonDTU/02456-Reinforcement-Learning-Project/blob/restructure_code/Continue_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INIT : Procgen, Drive, Git

# %%
# !pip install procgen

# %%
#Clone git
# !git clone -b restructure_code https://github.com/SebastianLarssonDTU/02456-Reinforcement-Learning-Project.git "my_project"
# Out:
# fatal: destination path 'my_project' already exists and is not an empty directory.

# %%
#update git
# %cd /content/my_project
! git pull
# Out:
# /content/my_project
# Already up to date.

# %%
import datatools as tools
from datatools import DATA_PATH, MODEL_PATH
#Mount drive
tools.mount_drive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # TESTING

# %%
#Import all custom files
import baseline
import datatools as tools
import hyperparameters as h
import model
import my_util
import policy
import ppo
import utils

#other imports
import torch

#import specific methods
from baseline import set_hyperparameters
from ppo import PPO
from experiments import run_experiment, print_list_of_experiments

# %%
INDEX = tools.create_index_table_from_txt_files()
INDEX
# Out:
#         total_steps num_envs num_levels  ... step_start Time spent Last Mean Reward
#  Value    8000000.0       32         10  ...        NaN    5:14:18         20.34375
#  Value    8000000.0       32         10  ...        NaN    5:30:18         19.53125
#  Value    8000000.0       32         10  ...        NaN    5:46:11         23.96875
#  Value    8000000.0       32         10  ...        NaN    5:41:20         28.15625
#  Value    8000000.0       32         10  ...        NaN    5:46:59          25.8125
#  Value    8000000.0       32         10  ...        NaN        NaN             23.0
#  Value    8000000.0       32         10  ...        NaN        NaN             24.5
#  Value    8000000.0       32         10  ...        NaN    8:55:30         16.28125
#  Value    8000000.0       32         10  ...        NaN    9:30:41         24.15625
#  Value    8000000.0       32         10  ...        NaN        NaN         22.03125
# ...

# %%
file_names = [x.strip() for x in INDEX['file_name']]
for i in range(len(file_names)):
  print("[{:2d}]: {}".format(i, file_names[i]))
# Out:
# [ 0]: Experiment0_Run_26Nov_15h21m41s
# [ 1]: Experiment1_Run_26Nov_15h22m38s
# [ 2]: Experiment2_Run_26Nov_22h02m36s
# [ 3]: Experiment2_Run_27Nov_11h05m48s
# [ 4]: Experiment4_Run_27Nov_11h07m20s
# [ 5]: Experiment3_Run_27Nov_18h03m39s
# [ 6]: Experiment4_Run_27Nov_18h11m00s
# [ 7]: Experiment5_Run_27Nov_16h37m42s
# [ 8]: Experiment6_Run_28Nov_12h09m43s
# [ 9]: Experiment3_Run_29Nov_16h30m27s
# [10]: Experiment7_Run_29Nov_16h32m47s
# [11]: Experiment7_Run_30Nov_14h45m32s
# [12]: Experiment8_Run_30Nov_22h21m06s
# [13]: Experiment7_50levels_Run_01Dec_07h28m45s
# [14]: Experiment2_50levels_Run_01Dec_10h07m41s
# [15]: Experiment2_100levels_Run_02Dec_09h27m30s
# [16]: Experiment7_100levels_Run_02Dec_09h29m48s
# [17]: Experiment8_50levels_Run_02Dec_17h18m34s
# [18]: Experiment8_10levels_Run_02Dec_09h48m26s
# [19]: Experiment2_100levels_Run_03Dec_10h48m24s
# [20]: Experiment8_50levels_Run_03Dec_14h53m09s
# [21]: Experiment8_10levels_Run_03Dec_11h04m34s
# ...

# %%
# run_experiment(2, levels=50, save_interval=5e5)

# %%
file_name = "Experiment2_50levels_Run_04Dec_18h10m32s_6004736steps"
set_hyperparameters(baseline="PPO")
h.value_clipping = True
h.num_levels = 50
model = PPO(print_output=True, eval=True, save_interval=5e5)
model.load_policy(file_name)
model.train()
# Out:
# Observation space: Box(0.0, 1.0, (3, 64, 64), float32)
# Action space: 15
# Loaded current model from models folder with name Experiment2_50levels_Run_04Dec_18h10m32s_6004736steps.pt
# Step: 6012928	Mean reward: 19.875
# Step: 6021120	Mean reward: 22.78125
# Step: 6029312	Mean reward: 21.78125
# Evaluation done with avg score of   3.936659
# Step: 6037504	Mean reward: 21.1875
# Step: 6045696	Mean reward: 21.21875
# Step: 6053888	Mean reward: 21.875
# Step: 6062080	Mean reward: 19.25
# Step: 6070272	Mean reward: 21.96875
# Step: 6078464	Mean reward: 22.71875
# Step: 6086656	Mean reward: 22.25
# Step: 6094848	Mean reward: 22.9375
# Step: 6103040	Mean reward: 21.375
# Step: 6111232	Mean reward: 21.375
# Step: 6119424	Mean reward: 21.90625
# Step: 6127616	Mean reward: 23.40625
# Step: 6135808	Mean reward: 19.8125
# Step: 6144000	Mean reward: 22.6875
# Step: 6152192	Mean reward: 21.25
# Step: 6160384	Mean reward: 20.03125
